# %% [markdown]
# # Melting Data for Olympics Project

# %% [markdown]
# ## 1. Preparing Notebook

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Matt\Documents\Data Analysis Course\Medal_Count_GDP_Project'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Cleaned_GDP_Data.csv'), index_col = False)

# %%
df_ath = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Cleaned_Athlete_Data.csv'), index_col = False)

# %%
df.head(20)
# Out:
#                    Country Name         1960         1961         1962  \
# 0                         Aruba          NaN          NaN          NaN
# 1   Africa Eastern and Southern   153.494439   152.873313   162.413188
# 2                   Afghanistan    59.773234    59.860900    58.458009
# 3    Africa Western and Central   107.932233   113.081647   118.831107
# 4                        Angola          NaN          NaN          NaN
# 5                       Albania          NaN          NaN          NaN
# 6                       Andorra          NaN          NaN          NaN
# 7                    Arab World          NaN          NaN          NaN
# 8          United Arab Emirates          NaN          NaN          NaN
# 9                     Argentina          NaN          NaN  1155.890717
# 10                      Armenia          NaN          NaN          NaN
# 11               American Samoa          NaN          NaN          NaN
# ...

# %%
df.shape
# Out:
# (270, 66)

# %% [markdown]
# ## 2. Using 'melt' function to match formatting of Athlete data set

# %%
df1 = pd.melt(df, id_vars = "Country Name", var_name = "Year", value_name = "GDP")
df1.head(50)
# Out:
#                       Country Name  Year          GDP
# 0                            Aruba  1960          NaN
# 1      Africa Eastern and Southern  1960   153.494439
# 2                      Afghanistan  1960    59.773234
# 3       Africa Western and Central  1960   107.932233
# 4                           Angola  1960          NaN
# 5                          Albania  1960          NaN
# 6                          Andorra  1960          NaN
# 7                       Arab World  1960          NaN
# 8             United Arab Emirates  1960          NaN
# 9                        Argentina  1960          NaN
# 10                         Armenia  1960          NaN
# 11                  American Samoa  1960          NaN
# 12             Antigua and Barbuda  1960          NaN
# 13                       Australia  1960  1810.619230
# 14                         Austria  1960   935.460427
# 15                      Azerbaijan  1960          NaN
# ...

# %%
df1.shape
# Out:
# (17550, 3)

# %% [markdown]
# ## 3. Checking Descriptive Statistics

# %%
df1.describe()
# Out:
#                  GDP
# count   12851.000000
# mean     7958.522193
# std     16053.126704
# min        12.802812
# 25%       531.021278
# 50%      1806.542548
# 75%      7296.594876
# max    189487.147100

# %%
df_ath.describe()
# Out:
#                   ID            Age    Height (cm)    Weight (kg)  \
# count  269731.000000  260416.000000  210917.000000  208204.000000
# mean    68264.949591      25.454776     175.338953      70.701778
# std     39026.253843       6.163869      10.518507      14.349027
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34655.500000      21.000000     168.000000      60.000000
# 50%     68233.000000      24.000000     175.000000      70.000000
# 75%    102111.000000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  269731.000000
# mean     1978.623073
# std        29.752055
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df1.to_csv(os.path.join(path, '02 Data','Prepared Data', 'Melted_GDP_Data.csv'))
