# %% [markdown]
# # Exploratory Visualizations

# %% [markdown]
# ## 1. Preparing Notebook

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Creating 'Path'
path = r'C:\Users\Matt\Documents\Data Analysis Course\Medal_Count_GDP_Project'

# %%
# Importing merged data sets
df_merged = pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'Merged_Data.csv'))

# %%
df_merged.head(10)
# Out:
#    Unnamed: 0     ID            Name Sex   Age  Weight (kg)  Height (cm)  \
# 0           0      1       A Dijiang   M  24.0        180.0         80.0
# 1           1   6848  Bai Chongguang   M  21.0        184.0         83.0
# 2           2   6854         Bai Mei   F  17.0        166.0         46.0
# 3           3  11225        Bi Zhong   M  23.0        188.0        110.0
# 4           4  17295      Cai Yanshu   M  28.0        169.0         79.0
# 5           5  17996    Cao Mianying   F  25.0        176.0         71.0
# 6           6  17996    Cao Mianying   F  25.0        176.0         71.0
# 7           7  19813         Chao Lu   M  22.0        180.0         75.0
# 8           8  20155       Chen Biao   M  21.0        188.0         80.0
# 9           9  20156   Chen Cailiang   M  22.0        165.0         63.0
#
#   Country Name Code        Games  Year  Season   Location  \
# 0        China  CHN  1992 Summer  1992  Summer  Barcelona
# ...

# %%
# Checking dataset shape
df_merged.shape
# Out:
# (164408, 19)

# %% [markdown]
# ## 2. Creating 'Medal Winner' Flag

# %%
# Creating flag using 'loc' funciton
df_merged.loc[df_merged['Medal'] == 'Gold', 'Medal Winner?'] = 'Yes'
df_merged.loc[df_merged['Medal'] == 'Silver', 'Medal Winner?'] = 'Yes'
df_merged.loc[df_merged['Medal'] == 'Bronze', 'Medal Winner?'] = 'Yes'

# %%
df_merged.loc[df_merged['Medal'] == 'None', 'Medal Winner?'] = 'No'

# %%
df_merged.head()
# Out:
#    Unnamed: 0     ID            Name Sex   Age  Weight (kg)  Height (cm)  \
# 0           0      1       A Dijiang   M  24.0        180.0         80.0
# 1           1   6848  Bai Chongguang   M  21.0        184.0         83.0
# 2           2   6854         Bai Mei   F  17.0        166.0         46.0
# 3           3  11225        Bi Zhong   M  23.0        188.0        110.0
# 4           4  17295      Cai Yanshu   M  28.0        169.0         79.0
#
#   Country Name Code        Games  Year  Season   Location  \
# 0        China  CHN  1992 Summer  1992  Summer  Barcelona
# 1        China  CHN  1992 Summer  1992  Summer  Barcelona
# 2        China  CHN  1992 Summer  1992  Summer  Barcelona
# 3        China  CHN  1992 Summer  1992  Summer  Barcelona
# 4        China  CHN  1992 Summer  1992  Summer  Barcelona
#
#                  Sport                                   Event Medal  \
# 0           Basketball             Basketball Men's Basketball  None
# ...

# %%
# Checking new flag
df_merged['Medal Winner?'].value_counts(dropna = False)
# Out:
# No     144357
# Yes     20051
# Name: Medal Winner?, dtype: int64

# %% [markdown]
# ## 3. Creating Visualizations

# %%
# Checking data set shape
df_merged.shape
# Out:
# (164408, 20)

# %%
df_merged.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Sex', 'Age', 'Weight (kg)', 'Height (cm)',
#        'Country Name', 'Code', 'Games', 'Year', 'Season', 'Location', 'Sport',
#        'Event', 'Medal', 'After 1960', 'Unnamed: 0.1', 'GDP', 'Medal Winner?'],
#       dtype='object')

# %%
# Dropping unneeded columns
df_trim = df_merged.drop(columns = ['Unnamed: 0', 'Code', 'After 1960', 'Unnamed: 0.1'])

# %%
df_trim.head()
# Out:
#       ID            Name Sex   Age  Weight (kg)  Height (cm) Country Name  \
# 0      1       A Dijiang   M  24.0        180.0         80.0        China
# 1   6848  Bai Chongguang   M  21.0        184.0         83.0        China
# 2   6854         Bai Mei   F  17.0        166.0         46.0        China
# 3  11225        Bi Zhong   M  23.0        188.0        110.0        China
# 4  17295      Cai Yanshu   M  28.0        169.0         79.0        China
#
#          Games  Year  Season   Location                Sport  \
# 0  1992 Summer  1992  Summer  Barcelona           Basketball
# 1  1992 Summer  1992  Summer  Barcelona               Boxing
# 2  1992 Summer  1992  Summer  Barcelona  Rhythmic Gymnastics
# 3  1992 Summer  1992  Summer  Barcelona            Athletics
# 4  1992 Summer  1992  Summer  Barcelona        Weightlifting
#
#                                     Event Medal         GDP Medal Winner?
# 0             Basketball Men's Basketball  None  366.460692            No
# ...

# %%
df_trim.dtypes
# Out:
# ID                 int64
# Name              object
# Sex               object
# Age              float64
# Weight (kg)      float64
# Height (cm)      float64
# Country Name      object
# Games             object
# Year               int64
# Season            object
# Location          object
# Sport             object
# Event             object
# Medal             object
# GDP              float64
# Medal Winner?     object
# dtype: object

# %%
# Creating a medal flag using numerical values
f_trim.loc[df_trim['Medal'] == 'Gold', 'Medal Flag'] = 1
df_trim.loc[df_trim['Medal'] == 'Silver', 'Medal Flag'] = 1
df_trim.loc[df_trim['Medal'] == 'Bronze', 'Medal Flag'] = 1
df_trim.loc[df_trim['Medal'] == 'None', 'Medal Flag'] = 0

# %%
df_trim.head()
# Out:
#       ID            Name Sex   Age  Weight (kg)  Height (cm) Country Name  \
# 0      1       A Dijiang   M  24.0        180.0         80.0        China
# 1   6848  Bai Chongguang   M  21.0        184.0         83.0        China
# 2   6854         Bai Mei   F  17.0        166.0         46.0        China
# 3  11225        Bi Zhong   M  23.0        188.0        110.0        China
# 4  17295      Cai Yanshu   M  28.0        169.0         79.0        China
#
#          Games  Year  Season   Location                Sport  \
# 0  1992 Summer  1992  Summer  Barcelona           Basketball
# 1  1992 Summer  1992  Summer  Barcelona               Boxing
# 2  1992 Summer  1992  Summer  Barcelona  Rhythmic Gymnastics
# 3  1992 Summer  1992  Summer  Barcelona            Athletics
# 4  1992 Summer  1992  Summer  Barcelona        Weightlifting
#
#                                     Event Medal         GDP Medal Winner?  \
# 0             Basketball Men's Basketball  None  366.460692            No
# ...

# %%
# Checking correlation
df_trim.corr()
# Out:
#                    ID       Age  Weight (kg)  Height (cm)      Year       GDP  \
# ID           1.000000 -0.003233    -0.015342    -0.010884  0.021575 -0.004134
# Age         -0.003233  1.000000     0.140768     0.205180  0.122115  0.135288
# Weight (kg) -0.015342  0.140768     1.000000     0.796922  0.068829  0.071651
# Height (cm) -0.010884  0.205180     0.796922     1.000000  0.044663  0.051014
# Year         0.021575  0.122115     0.068829     0.044663  1.000000  0.518115
# GDP         -0.004134  0.135288     0.071651     0.051014  0.518115  1.000000
# Medal Flag   0.013943  0.032328     0.084204     0.078827  0.044281  0.100242
#
#              Medal Flag
# ID             0.013943
# Age            0.032328
# Weight (kg)    0.084204
# Height (cm)    0.078827
# Year           0.044281
# GDP            0.100242
# Medal Flag     1.000000

# %%
# Creating subset
sub = df_trim [['Age', 'Weight (kg)', 'Height (cm)', 'Year', 'GDP', 'Medal Flag']]
sub
# Out:
#          Age  Weight (kg)  Height (cm)  Year           GDP  Medal Flag
# 0       24.0        180.0         80.0  1992    366.460692         0.0
# 1       21.0        184.0         83.0  1992    366.460692         0.0
# 2       17.0        166.0         46.0  1992    366.460692         0.0
# 3       23.0        188.0        110.0  1992    366.460692         0.0
# 4       28.0        169.0         79.0  1992    366.460692         0.0
# ...      ...          ...          ...   ...           ...         ...
# 164403  35.0        183.0         77.0  1994   5854.418117         0.0
# 164404  51.0        183.0         77.0  2010   9271.398396         0.0
# 164405  51.0        183.0         77.0  2010   9271.398396         0.0
# 164406  55.0        183.0         77.0  2014  10928.916010         0.0
# 164407  28.0          NaN          NaN  1994   2270.337325         0.0
#
# [164408 rows x 6 columns]

# %%
sub.corr()
# Out:
#                   Age  Weight (kg)  Height (cm)      Year       GDP  \
# Age          1.000000     0.140768     0.205180  0.122115  0.135288
# Weight (kg)  0.140768     1.000000     0.796922  0.068829  0.071651
# Height (cm)  0.205180     0.796922     1.000000  0.044663  0.051014
# Year         0.122115     0.068829     0.044663  1.000000  0.518115
# GDP          0.135288     0.071651     0.051014  0.518115  1.000000
# Medal Flag   0.032328     0.084204     0.078827  0.044281  0.100242
#
#              Medal Flag
# Age            0.032328
# Weight (kg)    0.084204
# Height (cm)    0.078827
# Year           0.044281
# GDP            0.100242
# Medal Flag     1.000000

# %% [markdown]
# ### Creating Heat Maps

# %%
# Creating matrix heatmap
plt.matshow(sub.corr())
plt.show()

# %%
# Adding axis labels, legend and titles
f = plt.figure(figsize=(6, 6)) # figure size 
plt.matshow(sub.corr(), fignum=f.number) # type of plot
plt.xticks(range(sub.shape[1]), sub.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(sub.shape[1]), sub.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# #### It seems like the only variables that have above a .50 correlation score is weight and height, as well as GDP and Year, which can be expected, since taller people weigh more and for the most part, a country's GDP raises with time.

# %% [markdown]
# ### Creating Scatterplots

# %%
# Creating Scatterplots
sns.lmplot(x = 'Weight (kg)', y = 'Height (cm)', data = df_trim)

# %% [markdown]
# #### As expected, the scatterplot shows the relationship between height and weight amongst the athletes is a strong positive relationship.

# %% [markdown]
# ### Creating Pair Plots

# %%
# Creating another subset for appropriate variables
sub_2 = sub[['GDP', 'Medal Flag', 'Weight (kg)', 'Height (cm)']]

# %%
# Creating pair plot
g = sns.pairplot(sub_2)

# %% [markdown]
# #### I would like to look closer at the relationship between GDP and the medal flag, as this project's purpose is to see if there's a correlation between a country's GDP and the amount of medals its athele's win.

# %% [markdown]
# ### Creating Categorical Plot

# %%
# Creating histogram based on 'GDP' to see what the distribution is of countries who have athletes that compete in the olympics.
sns.histplot(sub_2['GDP'], bins = 25, kde = True)
# Out:
# <AxesSubplot:xlabel='GDP', ylabel='Count'>

# %%
df_trim.loc[df_trim['GDP'] < 7500, 'GDP Category'] = 'Low GDP'
df_trim.loc[(df_trim['GDP'] >= 7500) & (df_trim['GDP'] <25000), 'GDP Category'] = 'Mid GDP'
df_trim.loc[df_trim['GDP'] >= 25000, 'GDP Category'] = 'High GDP'

# %%
df_trim['GDP Category'].value_counts(dropna = False)
# Out:
# Low GDP     67203
# High GDP    43163
# Mid GDP     41679
# NaN         12363
# Name: GDP Category, dtype: int64

# %%
sns.set(style="ticks")
g = sns.catplot(x="Year", y="GDP", hue="GDP Category", data=df_trim)

# %% [markdown]
# #### As time goes, overal GDP goes up, as well as the max GDP, representing the country with the highest GDP in the world.

# %% [markdown]
# ## 4. Revisiting Questions

# %% [markdown]
# #### 1. Most of my questions before the initial analysis dealt with medal count, which I have yet to figure out a good way to track properly. I also asked the question "Where do the most successful Olympians come from, and I'm guessing that will be apart of my spatial analysis in the next exercise.
# #### 2. The main hypothesis of this project is the higher the GDP, the better results a country sees in the Olympics. Based on how I'm tracking it now, it doesn't seem to be the case. However I do believe there's a better way to track the medal count of the countries.
