# %% [markdown]
# # Merging the Data Sets

# %% [markdown]
# ## 1. Preparing Notebook

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Matt\Documents\Data Analysis Course\Medal_Count_GDP_Project'

# %%
df_gdp = pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'Melted_GDP_Data.csv'))

# %%
df_gdp.head(10)
# Out:
#    Unnamed: 0                 Country Name  Year         GDP
# 0           0                        Aruba  1960         NaN
# 1           1  Africa Eastern and Southern  1960  153.494439
# 2           2                  Afghanistan  1960   59.773234
# 3           3   Africa Western and Central  1960  107.932233
# 4           4                       Angola  1960         NaN
# 5           5                      Albania  1960         NaN
# 6           6                      Andorra  1960         NaN
# 7           7                   Arab World  1960         NaN
# 8           8         United Arab Emirates  1960         NaN
# 9           9                    Argentina  1960         NaN

# %%
df_ath = pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'Formatted_Athlete_Data.csv'))

# %%
df_ath.head(10)
# Out:
#    ID                      Name Sex   Age  Weight (kg)  Height (cm)  \
# 0   1                 A Dijiang   M  24.0        180.0         80.0
# 1   2                  A Lamusi   M  23.0        170.0         60.0
# 2   5  Christine Jacoba Aaftink   F  21.0        185.0         82.0
# 3   5  Christine Jacoba Aaftink   F  21.0        185.0         82.0
# 4   5  Christine Jacoba Aaftink   F  25.0        185.0         82.0
# 5   5  Christine Jacoba Aaftink   F  25.0        185.0         82.0
# 6   5  Christine Jacoba Aaftink   F  27.0        185.0         82.0
# 7   5  Christine Jacoba Aaftink   F  27.0        185.0         82.0
# 8   6           Per Knut Aaland   M  31.0        188.0         75.0
# 9   6           Per Knut Aaland   M  31.0        188.0         75.0
#
#     Country Name Code        Games  Year  Season     Location  \
# 0          China  CHN  1992 Summer  1992  Summer    Barcelona
# 1          China  CHN  2012 Summer  2012  Summer       London
# ...

# %% [markdown]
# ## 2. Checking Data Types for merge

# %%
df_ath.dtypes
# Out:
# ID                int64
# Name             object
# Sex              object
# Age             float64
# Weight (kg)     float64
# Height (cm)     float64
# Country Name     object
# Code             object
# Games            object
# Year              int64
# Season           object
# Location         object
# Sport            object
# Event            object
# Medal            object
# After 1960       object
# dtype: object

# %%
df_gdp.dtypes
# Out:
# Unnamed: 0        int64
# Country Name     object
# Year              int64
# GDP             float64
# dtype: object

# %%
df_gdp['Year'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## 3. Merging Data Sets

# %%
df_merged = df_ath.merge(df_gdp, on = ['Year', 'Country Name'])

# %%
df_merged.head(50)
# Out:
#        ID            Name Sex   Age  Weight (kg)  Height (cm) Country Name  \
# 0       1       A Dijiang   M  24.0        180.0         80.0        China
# 1    6848  Bai Chongguang   M  21.0        184.0         83.0        China
# 2    6854         Bai Mei   F  17.0        166.0         46.0        China
# 3   11225        Bi Zhong   M  23.0        188.0        110.0        China
# 4   17295      Cai Yanshu   M  28.0        169.0         79.0        China
# 5   17996    Cao Mianying   F  25.0        176.0         71.0        China
# 6   17996    Cao Mianying   F  25.0        176.0         71.0        China
# 7   19813         Chao Lu   M  22.0        180.0         75.0        China
# 8   20155       Chen Biao   M  21.0        188.0         80.0        China
# 9   20156   Chen Cailiang   M  22.0        165.0         63.0        China
# 10  20190    Chen Fengqin   F  27.0        178.0         60.0        China
# ...

# %%
df_merged.to_csv(os.path.join(path, '02 Data','Prepared Data', 'Merged_Data_2.csv'))
